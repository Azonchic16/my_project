# %%
import numpy as np
import matplotlib.pyplot as plt
import math
a = int(input())
b = int(input())
n = int(input())
x = np.linspace(a,b,n+1)
f = lambda b: (np.log(b+2)*np.sin(b/2))/2 
y = f(x)
def func1(t: float):
    polinom = 0
    for k in range(len(x)):
        p = 1
        for j in range(len(x)):
            if k != j:
                p = p*(t-x[j])/(x[k]-x[j])
        polinom = polinom + y[k]*p
    return polinom

    
c = np.linspace(0,10,100)
g = [func1(i) for i in c]
x_err = np.array([x[i] + (b-a)/(4*n) for i in range(0, len(x)-1)])
pol_chetv = np.array([func1(elem) for elem in x_err])
y_chetv = f(x_err)
r = abs(pol_chetv - y_chetv)
fig, axs = plt.subplots(nrows= 1 , ncols= 2 )
axs[0].plot(c,g,label = 'полином')
axs[0].plot(c,f(c),label = 'функция')
axs[0].legend(fontsize = 14)
axs[0].errorbar(x_err, pol_chetv, yerr=r, linestyle='none', ecolor = 'k',elinewidth=0.5, capsize=2, capthick=1)
axs[0].grid(which='major')
axs[1].scatter(x_err, r)
fig.set_size_inches(14,7)
plt.show()
# Out:
# 0
# 10
# 100

# %% [markdown]
# ##

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
a = int(input())
b = int(input())
n = int(input())
x = np.linspace(a,b,n+1)
f = lambda b: (np.log(b+2)*np.sin(b/2))/2 
y = f(x)

q = [0.5*(a+b)+0.5*(b-a)*np.cos(np.pi*(2*k+1)/(2*n+2)) for k in range(n+1)]
x_cheb = np.array(q[::-1])
y_cheb = f(x_cheb)

def func2(t: float):
    polinom = 0
    for k in range(len(x_cheb)):
        p = 1
        for j in range(len(x_cheb)):
            if k != j:
                p = p*(t-x_cheb[j])/(x_cheb[k]-x_cheb[j])
        polinom = polinom + y_cheb[k]*p
    return polinom

    
c = np.linspace(0,10,100)
g_cheb = [func2(i) for i in c]
x_err_cheb = np.array([x_cheb[k] + (x_cheb[k+1] - x_cheb[k])/4 for k in range(n)])
pol_chetv_cheb = np.array([func2(elem) for elem in x_err_cheb])
y_chetv_cheb = f(x_err_cheb)
r_cheb = abs(y_chetv_cheb - pol_chetv_cheb)
fig, axs = plt.subplots(nrows = 1, ncols = 2)
axs[0].plot(c,g_cheb,label = 'полином чебышева')
axs[0].plot(c,f(c),label = 'функция')
axs[0].legend(fontsize = 14)
axs[0].errorbar(x_err_cheb, pol_chetv_cheb, yerr=r_cheb, linestyle='none', ecolor = 'k',elinewidth=0.5, capsize=2, capthick=1)
axs[1].scatter(x_err_cheb, r_cheb)
fig.set_size_inches(14,7)
plt.show()
# Out:
# 0
# 10
# 100
# [1.51896724e-16 6.52689708e-17 8.06646416e-17 1.33573708e-16
#  1.07552856e-16 7.80625564e-17 8.67361738e-17 2.08166817e-17
#  9.02056208e-17 1.31838984e-16 1.04083409e-16 1.38777878e-16
#  1.94289029e-16 1.24900090e-16 2.35922393e-16 1.94289029e-16
#  3.88578059e-16 3.88578059e-16 1.94289029e-16 5.55111512e-17
#  4.99600361e-16 3.33066907e-16 4.99600361e-16 1.38777878e-15
#  6.66133815e-16 0.00000000e+00 1.66533454e-15 1.11022302e-15
#  1.66533454e-15 5.55111512e-16 5.55111512e-16 1.11022302e-16
#  6.66133815e-16 1.33226763e-15 0.00000000e+00 1.88737914e-15
#  1.11022302e-16 1.33226763e-15 1.99840144e-15 2.33146835e-15
#  2.10942375e-15 3.33066907e-16 8.88178420e-16 1.11022302e-16
#  7.77156117e-16 7.77156117e-16 3.33066907e-16 1.11022302e-16
#  1.22124533e-15 7.77156117e-16 1.11022302e-16 4.44089210e-16
#  2.22044605e-16 2.22044605e-16 1.66533454e-16 2.49800181e-16
#  1.94289029e-16 5.55111512e-17 1.30104261e-17 1.11022302e-16
#  5.55111512e-17 8.32667268e-17 3.33066907e-16 2.22044605e-16
#  2.77555756e-16 1.11022302e-15 3.33066907e-16 7.77156117e-16
#  9.99200722e-16 1.11022302e-16 4.44089210e-16 2.22044605e-16
#  5.55111512e-16 4.44089210e-16 2.22044605e-16 6.66133815e-16
#  2.22044605e-16 2.22044605e-16 4.44089210e-16 6.66133815e-16
#  1.33226763e-15 2.22044605e-16 2.22044605e-16 4.44089210e-16
#  4.44089210e-16 4.44089210e-16 2.22044605e-16 2.22044605e-16
#  2.22044605e-16 2.22044605e-16 8.88178420e-16 1.11022302e-15
#  2.22044605e-16 1.55431223e-15 6.66133815e-16 0.00000000e+00
#  6.66133815e-16 1.33226763e-15 8.88178420e-16 8.88178420e-16] погрешности для распределения чебышева

# %%
import sympy as sp
import math
x = Symbol('x')
sp.plot(np.e**(x/3))
